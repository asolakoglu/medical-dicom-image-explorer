# %%
import pydicom
import numpy as np
import matplotlib.pyplot as plt

# %%
ds = pydicom.dcmread("../data/raw/db/db_test_nd152.dcm") #dicom read ile de dicom dosyasını okuduk ve ds içine atadık.

print(ds)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 208
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.9590.100.1.2.266060268811441045340874576662853279079
# (0002,0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.3.6.1.4.1.9590.100.1.3.100.7.1
# (0002,0013) Implementation Version Name         SH: 'MATLAB IPT 7.1'
# -------------------------------------------------
# (0008,0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008,0018) SOP Instance UID                    UI: 1.3.6.1.4.1.9590.100.1.2.266060268811441045340874576662853279079
# (0008,0020) Study Date                          DA: ''
# (0008,0023) Content Date                        DA: '20121012'
# ...

# %%
image = ds.pixel_array # pixel_array ile dicom dosyasının içindeki görüntü verisini aldık.

print(" Shape:", image.shape ),
print(" Min:", np.min(image)),
print(" Max:", np.max(image))
# Out:
#  Shape: (3008, 3008)
#  Min: 27
#  Max: 4094

# %%
plt.imshow(image)

# %%
plt.imshow(image, cmap="gray")
